# %% [markdown]
# # Using the Explode methode in pandas

# %% [markdown]
# ## Importing libraries & Loading DataFrame

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast
df = pd.read_csv('C:/Users/DELL/Desktop/SQL/Data_analysis/data_jobs.csv')

# %% [markdown]
# ## Data Cleanup

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x) # This transforms the string into a list

# %% [markdown]
# ## Creating a copy of the original df and call it df_da
# ### Filter it by job_title_short == 'Data Analyst'

# %%
df_da = df[df['job_title_short'] == 'Data Analyst'].copy()

# %% [markdown]
# ## Aggregating the skills on monthly basis
# ### 1. Extracting the months from job_posted_date

# %% [markdown]
# ### 2. Creating job_posted_month_no column

# %%
df_da['job_posted_month_no'] = df_da['job_posted_date'].dt.month

# %%
df_da['job_posted_month_no'].value_counts()
# Out:
# job_posted_month_no
# 1     23585
# 8     18628
# 2     16558
# 3     16243
# 10    16239
# 7     16095
# 6     16008
# 4     15514
# 11    15230
# 9     14969
# 12    13583
# 5     13423
# Name: count, dtype: int64

# %% [markdown]
# ## Exploring job_skills

# %% [markdown]
# ### Creating a new data frame for that

# %%
df_da_explode= df_da.explode('job_skills')
df_da_explode.head()
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1 2023-01-14 13:18:07                  False                 False
# ...

# %% [markdown]
# ### Pivoting df_da_explode

# %%
df_da_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size')
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                      197.0      17.0    551.0     63.0         2.0     20.0
# 2                      169.0       2.0    448.0     49.0         NaN     14.0
# 3                      181.0       4.0    442.0     34.0         NaN     23.0
# 4                      155.0       4.0    413.0     22.0         NaN     11.0
# 5                      128.0       8.0    310.0     30.0         NaN     19.0
# 6                      164.0      14.0    393.0     29.0         NaN     14.0
# 7                      207.0       4.0    366.0     15.0         NaN      8.0
# 8                      197.0       3.0    413.0     21.0         NaN     12.0
# 9                      118.0       4.0    317.0     21.0         NaN     14.0
# 10                     173.0      11.0    350.0     40.0         NaN     19.0
# 11                     169.0       7.0    293.0     24.0         NaN     19.0
# ...

# %% [markdown]
# ### Fill the NaN with 0

# %%
df_da_pivot = df_da_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)
df_da_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %% [markdown]
# ### Creating a row to sum up total of each skill value

# %%
df_da_pivot.loc['Total']= df_da_pivot.sum()
df_da_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %% [markdown]
# ### Sorting the total row

# %%
df_da_pivot.loc['Total'].sort_values(ascending=False)
# Out:
# job_skills
# sql          92428
# excel        66860
# python       57190
# tableau      46455
# power bi     39380
#              ...
# capacitor        1
# nuxt.js          1
# msaccess         1
# ovh              1
# suse             1
# Name: Total, Length: 235, dtype: int64

# %% [markdown]
# ### Indexing the total row

# %%
df_da_pivot=df_da_pivot[df_da_pivot.loc['Total'].sort_values(ascending=False).index]
df_da_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi      r    sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285   3607   3830
# 2                     7947   5772    4751     3936      3307   2576   2634
# 3                     7868   5675    4741     4051      3176   2650   2554
# 4                     7553   5496    4557     3776      3106   2399   2598
# 5                     6617   4773    4070     3245      2695   2093   1940
# 6                     7584   5724    4707     3812      3275   2442   2174
# 7                     7687   5513    4831     3928      3350   2444   2118
# 8                     8823   6482    5576     4533      3859   2975   2560
# 9                     6829   4886    4229     3446      3118   2146   1880
# 10                    7474   5217    4693     3709      3340   2380   2114
# 11                    6652   4776    4233     3284      3012   2159   1738
# ...

# %% [markdown]
# ### Dropping the total row

# %%
df_da_pivot = df_da_pivot.drop('Total')
df_da_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
# ...

# %%
df_da_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
# ...

# %% [markdown]
# ### Ploting df_da_pivot

# %%
df_da_pivot.iloc[:, :5].plot(kind='line')
plt.title('Trending Top 5 Skills for Data Analysts per month')
plt.ylabel('Job Count')
plt.xlabel('')
plt.show()

# %%
df_da_pivot = df_da_pivot.reset_index()
df_da_pivot['job_posted_month'] = df_da_pivot['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b')) # This transforms the number into a month example Jan instead of january after creating a new column called job_posted_month_no
df_da_pivot = df_da_pivot.set_index('job_posted_month')
df_da_pivot = df_da_pivot.drop('job_posted_month_no', axis=1)

df_da_pivot.iloc[:, :5].plot(kind='line')
plt.title('Trending Top 5 Skills for Data Analysts per month')
plt.ylabel('Job Count')
plt.xlabel('')
plt.show()
